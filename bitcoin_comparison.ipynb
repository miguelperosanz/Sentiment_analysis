# %%
# Read the total file and choose the ones who mention bitcoin. We will use "buy" and "sell" as labels for the sentiment
import pandas as pd


tweets = pd.read_csv('./sentiments_tweets_FINAL.csv')

hundredtweets=tweets.iloc[0:100,:]

import csv
hundredtweets.to_csv('./hundredtweets2.csv', index=False, quoting=csv.QUOTE_ALL)

# %%
hundredtweets
# Out:
#                          Date  \
# 0   2018-04-09 18:00:00+00:00
# 1   2018-04-02 17:58:40+00:00
# 2   2019-04-11 20:20:00+00:00
# 3   2019-05-15 17:43:43+00:00
# 4   2019-05-15 17:06:11+00:00
# ..                        ...
# 95  2019-01-30 17:08:36+00:00
# 96  2019-01-26 22:04:11+00:00
# 97  2019-01-25 15:52:09+00:00
# 98  2019-01-23 21:00:47+00:00
# 99  2019-01-23 20:48:59+00:00
#
#                                                 Tweet  1_stars  2_stars  \
# 0    News via @livemint: @RBI bars banks from link...     0.66     0.20
# 1    Newsfeed from @payments_source : How an Afric...     0.69     0.20
# 2                      Is that Bitcoin? Not my thing      0.56     0.29
# 3                    I have zero opinion on bitcoin.      0.72     0.15
# 4             bitcoin? you have the wrong girl here.      0.65     0.19
# ..                                                ...      ...      ...
# 95   Aljazeera reported on January 29 that the cen...     0.51     0.21
# ...

# %%
#1 = bad, 2=neutral, 3 = good

# %%
tweets = pd.read_csv('./hundredtweetsFINAL.csv')
tweets
# Out:
#                          Date  \
# 0   2018-04-09 18:00:00+00:00
# 1   2018-04-02 17:58:40+00:00
# 2   2019-04-11 20:20:00+00:00
# 3   2019-05-15 17:43:43+00:00
# 4   2019-05-15 17:06:11+00:00
# ..                        ...
# 95  2019-01-30 17:08:36+00:00
# 96  2019-01-26 22:04:11+00:00
# 97  2019-01-25 15:52:09+00:00
# 98  2019-01-23 21:00:47+00:00
# 99  2019-01-23 20:48:59+00:00
#
#                                                 Tweet  1_stars  2_stars  \
# 0    News via @livemint: @RBI bars banks from link...     0.66     0.20
# 1    Newsfeed from @payments_source : How an Afric...     0.69     0.20
# 2                      Is that Bitcoin? Not my thing      0.56     0.29
# 3                    I have zero opinion on bitcoin.      0.72     0.15
# 4             bitcoin? you have the wrong girl here.      0.65     0.19
# ..                                                ...      ...      ...
# 95   Aljazeera reported on January 29 that the cen...     0.51     0.21
# ...

# %%
onestar_model = tweets['1_stars'].sum()
twostars_model = tweets['2_stars'].sum()
threestars_model = tweets['3_stars'].sum()
fourstars_model = tweets['4_stars'].sum()
fivestars_model = tweets['5_stars'].sum()

# %%
onestar_personal = len(tweets[tweets['Personal']==1])
twostars_personal = len(tweets[tweets['Personal']==2])
threestars_personal = len(tweets[tweets['Personal']==3])

# %%
onestar_model2 = len(tweets[tweets['Model']==1])
twostars_model2 = len(tweets[tweets['Model']==2])
threestars_model2 = len(tweets[tweets['Model']==3])

# %%
onestar_model3 = len(tweets[tweets['Model_max']==1])
twostars_model3 = len(tweets[tweets['Model_max']==2])
threestars_model3 = len(tweets[tweets['Model_max']==3])

# %%
onestar_model4 = len(tweets[tweets['Model3']==1])
twostars_model4 = len(tweets[tweets['Model3']==2])
threestars_model4 = len(tweets[tweets['Model3']==3])

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Fake dataset
height = [onestar_model, twostars_model, threestars_model, fourstars_model, fivestars_model]
bars = ('1 star', '2 stars', '3 stars', '4 stars', '5 stars')
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))
 
# Add title and axis names
plt.title('Model values')
plt.xlabel('categories')
plt.ylabel('values')
 
# Limits for the Y axis
plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
height = [onestar_personal, twostars_personal, threestars_personal]
bars = ('onestar_personal', 'twostars_personal', 'threestars_personal')
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5))
 
# Add title and axis names
plt.title('Personal values')
plt.xlabel('categories')
plt.ylabel('values')
 
# Limits for the Y axis
plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
height = [onestar_model2, twostars_model2, threestars_model2]
bars = ('onestar_model', 'twostars_model', 'threestars_model')
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5))
 
# Add title and axis names
plt.title('Model values')
plt.xlabel('categories')
plt.ylabel('values')
 
# Limits for the Y axis
plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
height = [onestar_personal, twostars_personal, threestars_personal]
bars = ('onestar_personal', 'twostars_personal', 'threestars_personal')
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5))
 
# Add title and axis names
plt.title('Personal values')
plt.xlabel('categories')
plt.ylabel('values')
 
# Limits for the Y axis
plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
height = [onestar_model3, twostars_model3, threestars_model3]
bars = ('onestar_model', 'twostars_model', 'threestars_model')
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5))
 
# Add title and axis names
plt.title('Model values')
plt.xlabel('categories')
plt.ylabel('values')
 
# Limits for the Y axis
plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
height = [onestar_model4, twostars_model4, threestars_model4]
bars = ('onestar_model', 'twostars_model', 'threestars_model')
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5))
 
# Add title and axis names
plt.title('Model values')
plt.xlabel('categories')
plt.ylabel('values')
 
# Limits for the Y axis
plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
len(tweets[tweets['Accuracy_model3']==1])
# Out:
# 47

# %% [markdown]
# # LET'S STUDY NOW "EXTREM" TWEETS: TWEETS OBVIOUSLY GOOD OR OBVIOUSLY BAD.

# %%
import pandas as pd


tweets_good = pd.read_csv('./good_tweets.csv')
tweets_bad = pd.read_csv('./bad_tweets.csv')

# %%
tweets_good
# Out:
#                          Date  \
# 0   2020-08-12 08:00:02+00:00
# 1   2020-08-10 08:00:02+00:00
# 2   2020-05-15 22:20:42+00:00
# 3   2018-11-22 19:03:33+00:00
# 4   2020-07-27 01:40:54+00:00
# 5   2020-07-21 14:33:52+00:00
# 6   2020-06-07 00:07:00+00:00
# 7   2020-05-03 14:25:56+00:00
# 8   2020-05-11 21:29:00+00:00
# 9   2020-05-25 20:03:19+00:00
# 10  2020-04-22 11:27:25+00:00
# 11  2019-10-03 17:11:01+00:00
# 12  2019-10-17 03:21:43+00:00
# 13  2019-09-13 18:26:54+00:00
# 14  2019-07-17 23:31:50+00:00
# 15  2019-06-07 13:41:14+00:00
# 16  2019-06-23 12:34:31+00:00
# 17  2018-03-19 01:54:03+00:00
# 18  2018-04-05 11:32:18+00:00
# 19  2019-01-03 19:31:22+00:00
# 20  2018-01-23 03:17:59+00:00
# 21  2019-02-07 00:10:45+00:00
# 22  2019-02-26 00:41:59+00:00
# 23  2019-09-28 04:16:17+00:00
# 24  2019-07-13 22:13:06+00:00
# 25  2018-10-21 14:51:00+00:00
# 26        2018-06-12 12:15:10
# 27        2019-02-03 16:51:31
# 28        2019-02-23 17:26:39
# 29        2019-05-03 18:09:11
# ...

# %%
tweets_bad
# Out:
#                          Date  \
# 0   2018-10-02 02:14:41+00:00
# 1   2019-11-25 04:24:57+00:00
# 2   2019-09-24 19:34:09+00:00
# 3   2020-01-02 17:02:22+00:00
# 4   2018-09-06 05:42:08+00:00
# 5   2018-09-06 05:46:05+00:00
# 6   2018-06-22 20:18:15+00:00
# 7   2018-03-15 06:44:02+00:00
# 8   2018-03-29 15:17:44+00:00
# 9   2018-03-19 02:46:03+00:00
# 10  2018-01-11 01:45:19+00:00
# 11  2020-07-21 10:24:03+00:00
# 12  2018-09-12 18:25:19+00:00
# 13  2020-07-17 13:13:03+00:00
# 14  2018-01-30 03:10:34+00:00
# 15  2018-01-30 01:13:57+00:00
# 16  2020-03-10 00:33:39+00:00
# 17        2018-03-06 23:21:34
# 18        2018-07-02 22:50:16
# 19  2019-01-20 23:34:06+00:00
# 20        2018-02-16 17:14:01
# 21  2019-10-23 13:07:57+00:00
# 22  2019-05-17 19:27:42+00:00
# 23  2018-05-22 22:08:09+00:00
# 24        2019-01-31 10:18:12
# 25        2019-11-04 20:52:55
# 26        2019-09-20 21:42:52
# 27        2019-05-04 15:54:59
# 28  2019-11-11 07:00:48+00:00
# 29  2019-11-25 08:30:26+00:00
# ...

# %% [markdown]
# LET'S START WITH THE POSITIVE TWEETS

# %%
one_star_good = tweets_good['1_stars'].sum()
two_stars_good = tweets_good['2_stars'].sum()
three_stars_good= tweets_good['3_stars'].sum()
four_stars_good = tweets_good['4_stars'].sum()
five_stars_good = tweets_good['5_stars'].sum()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
fig= plt.figure(figsize=(14,7))

height = [one_star_good, two_stars_good, three_stars_good, four_stars_good, five_stars_good]
bars = ('1 star', '2 stars', '3 stars', '4 stars', '5 stars')
y_pos = np.arange(len(bars))
 

plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))

plt.title('Model applied to the set of positive tweets, adding the rates for every star with .sum')
plt.xlabel('categories')
plt.ylabel('added total value for every star')
 

plt.ylim(0,14)
 

plt.xticks(y_pos, bars)

plt.show()

# %%
one_star_good2 = len(tweets_good[tweets_good['winning_star']==1])
two_stars_good2 = len(tweets_good[tweets_good['winning_star']==2])
three_stars_good2 = len(tweets_good[tweets_good['winning_star']==3])
four_stars_good2 = len(tweets_good[tweets_good['winning_star']==4])
five_stars_good2 = len(tweets_good[tweets_good['winning_star']==5])

# %%
import numpy as np
import matplotlib.pyplot as plt
 
fig= plt.figure(figsize=(14,7))

height = [one_star_good2, two_stars_good2, three_stars_good2, four_stars_good2, five_stars_good2]
bars = ('1 star', '2 stars', '3 stars', '4 stars', '5 stars')
y_pos = np.arange(len(bars))
 

plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))

plt.title('Model applied to the set of positive tweets, just counting how many times every star "won"')
plt.xlabel('categories')
plt.ylabel('Number of times that every label "won"')
 

plt.ylim(0,18)
 

plt.xticks(y_pos, bars)

plt.show()

# %% [markdown]
# LET'S START WITH THE NEGATIVE TWEETS NOW:

# %%
one_star_bad = tweets_bad['1_stars'].sum()
two_stars_bad = tweets_bad['2_stars'].sum()
three_stars_bad = tweets_bad['3_stars'].sum()
four_stars_bad = tweets_bad['4_stars'].sum()
five_stars_bad = tweets_bad['5_stars'].sum()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
fig= plt.figure(figsize=(14,7))

height = [one_star_bad, two_stars_bad, three_stars_bad, four_stars_bad, five_stars_bad]
bars = ('1 star', '2 stars', '3 stars', '4 stars', '5 stars')
y_pos = np.arange(len(bars))
 

plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))

plt.title('Model applied to the set of negative tweets, adding the rates for every star with .sum()')
plt.xlabel('categories')
plt.ylabel('added total value for every star')
 

plt.ylim(0,23)
 

plt.xticks(y_pos, bars)

plt.show()

# %%
one_star_bad2 = len(tweets_bad[tweets_bad['winning_star']==1])
two_stars_bad2 = len(tweets_bad[tweets_bad['winning_star']==2])
three_stars_bad2 = len(tweets_bad[tweets_bad['winning_star']==3])
four_stars_bad2 = len(tweets_bad[tweets_bad['winning_star']==4])
five_stars_bad2 = len(tweets_bad[tweets_bad['winning_star']==5])

# %%
import numpy as np
import matplotlib.pyplot as plt
 
fig= plt.figure(figsize=(14,7))

height = [one_star_bad2, two_stars_bad2, three_stars_bad2, four_stars_bad2, five_stars_bad2]
bars = ('1 star', '2 stars', '3 stars', '4 stars', '5 stars')
y_pos = np.arange(len(bars))
 

plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))

plt.title('Model applied to the set of negative tweets, just counting how many times every star "won"')
plt.xlabel('categories')
plt.ylabel('Number of times that every label "won"')
 

plt.ylim(0,35)
 

plt.xticks(y_pos, bars)

plt.show()
